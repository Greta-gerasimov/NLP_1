# %% [markdown]
# <a href="https://colab.research.google.com/github/Greta-gerasimov/NLP_1/blob/L10-11%2FMT_with%2Fout_attention/hw11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
import transformers

# %%
import tensorflow_datasets as tfds
import tensorflow as tf

import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import unicodedata
import re
import os
import time
import io

# %%
from transformers import BertTokenizer

# %% [markdown]
# dataset

# %%
examples, metadata = tfds.load('ted_hrlr_translate/ru_to_en', with_info=True,
                               as_supervised=True)
train_examples, val_examples = examples['train'], examples['validation']
# Out:
# Downloading and preparing dataset 124.94 MiB (download: 124.94 MiB, generated: Unknown size, total: 124.94 MiB) to /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/208106 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0.incompleteESXYZA/ted_hrlr_translate-trai…
# Generating validation examples...:   0%|          | 0/4805 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0.incompleteESXYZA/ted_hrlr_translate-vali…
# Generating test examples...:   0%|          | 0/5476 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0.incompleteESXYZA/ted_hrlr_translate-test…
# Dataset ted_hrlr_translate downloaded and prepared to /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0. Subsequent calls will reuse this data.

# %%
tokenizer_en = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    (en.numpy() for pt, en in train_examples), target_vocab_size=2**13)

tokenizer_pt = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    (pt.numpy() for pt, en in train_examples), target_vocab_size=2**13)

# %%
BUFFER_SIZE = 20000
BATCH_SIZE = 64
MAX_LENGTH = 40

# %% [markdown]
# ## **начальный и конечный токен/энкодер**

# %%
def encode(lang1, lang2):
  lang1 = [tokenizer_pt.vocab_size] + tokenizer_pt.encode(
      lang1.numpy()) + [tokenizer_pt.vocab_size+1]

  lang2 = [tokenizer_en.vocab_size] + tokenizer_en.encode(
      lang2.numpy()) + [tokenizer_en.vocab_size+1]

  return lang1, lang2

# %%
# энкодер
def tf_encode(pt, en):
  result_pt, result_en = tf.py_function(encode, [pt, en], [tf.int64, tf.int64])
  result_pt.set_shape([None])
  result_en.set_shape([None])

  return result_pt, result_en

# %%
def filter_max_length(x, y, max_length=MAX_LENGTH):
  return tf.logical_and(tf.size(x) <= max_length,
                        tf.size(y) <= max_length)

# %%
train_dataset = train_examples.map(tf_encode)
train_dataset = train_dataset.filter(filter_max_length)
# cache the dataset to memory to get a speedup while reading from it.
train_dataset = train_dataset.cache()
train_dataset = train_dataset.shuffle(BUFFER_SIZE).padded_batch(BATCH_SIZE)
train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE)


val_dataset = val_examples.map(tf_encode)
val_dataset = val_dataset.filter(filter_max_length).padded_batch(BATCH_SIZE)

# %%
pt_batch, en_batch = next(iter(val_dataset))
pt_batch, en_batch
# Out:
# (<tf.Tensor: shape=(64, 38), dtype=int64, numpy=
#  array([[8179,   57,   86, ...,    0,    0,    0],
#         [8179,    3,   38, ...,    0,    0,    0],
#         [8179,   57,  135, ...,    0,    0,    0],
#         ...,
#         [8179,    3,    7, ...,    0,    0,    0],
#         [8179,  138,  250, ...,    0,    0,    0],
#         [8179,   19,    7, ...,    0,    0,    0]])>,
#  <tf.Tensor: shape=(64, 40), dtype=int64, numpy=
#  array([[8245,   90,  101, ...,    0,    0,    0],
#         [8245,   70,   25, ...,    0,    0,    0],
#         [8245,   90,  153, ...,    0,    0,    0],
#         ...,
#         [8245,    4,   18, ...,    0,    0,    0],
#         [8245,   19,   59, ...,    0,    0,    0],
#         [8245,   24,   18, ...,    0,    0,    0]])>)

# %%
def get_angles(pos, i, d_model):
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

# %%
def positional_encoding(position, d_model):
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)

  # apply sin to even indices in the array; 2i
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

  # apply cos to odd indices in the array; 2i+1
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

  pos_encoding = angle_rads[np.newaxis, ...]

  return tf.cast(pos_encoding, dtype=tf.float32)

# %% [markdown]
# masking

# %%
def create_padding_mask(seq):
  seq = tf.cast(tf.math.equal(seq, 0), tf.float32)

  # add extra dimensions to add the padding
  # to the attention logits.
  return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

# %%
def create_look_ahead_mask(size):
  mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
  return mask  # (seq_len, seq_len)

# %% [markdown]
# Attention

# %%
def scaled_dot_product_attention(q, k, v, mask):
  """Calculate the attention weights.
  q, k, v must have matching leading dimensions.
  k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
  The mask has different shapes depending on its type(padding or look ahead)
  but it must be broadcastable for addition.

  Args:
    q: query shape == (..., seq_len_q, depth)
    k: key shape == (..., seq_len_k, depth)
    v: value shape == (..., seq_len_v, depth_v)
    mask: Float tensor with shape broadcastable
          to (..., seq_len_q, seq_len_k). Defaults to None.

  Returns:
    output, attention_weights
  """

  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)

  # scale matmul_qk
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
  if mask is not None:
    scaled_attention_logits += (mask * -1e9)

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

  return output, attention_weights

# %%
def print_out(q, k, v):
  temp_out, temp_attn = scaled_dot_product_attention(
      q, k, v, None)
  print ('Attention weights are:')
  print (temp_attn)
  print ('Output is:')
  print (temp_out)

# %% [markdown]
# multiheadattention

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads):
    super(MultiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model

    assert d_model % self.num_heads == 0

    self.depth = d_model // self.num_heads

    self.wq = tf.keras.layers.Dense(d_model)
    self.wk = tf.keras.layers.Dense(d_model)
    self.wv = tf.keras.layers.Dense(d_model)

    self.dense = tf.keras.layers.Dense(d_model)

  def split_heads(self, x, batch_size):
    """Split the last dimension into (num_heads, depth).
    Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
    """
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])

  def call(self, v, k, q, mask):
    batch_size = tf.shape(q)[0]

    q = self.wq(q)  # (batch_size, seq_len, d_model)
    k = self.wk(k)  # (batch_size, seq_len, d_model)
    v = self.wv(v)  # (batch_size, seq_len, d_model)

    q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
    k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
    v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)

    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(
        q, k, v, mask)

    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

    concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

    output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)

    return output, attention_weights

# %%
def point_wise_feed_forward_network(d_model, dff):
  return tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
      tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
  ])

# %% [markdown]
# encoder

# %%
class EncoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(EncoderLayer, self).__init__()

    self.mha = MultiHeadAttention(d_model, num_heads)
    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)

  def call(self, x, training, mask):

    attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
    attn_output = self.dropout1(attn_output, training=training)
    out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)

    ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
    ffn_output = self.dropout2(ffn_output, training=training)
    out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)

    return out2

# %% [markdown]
# Decoder

# %%
class DecoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(DecoderLayer, self).__init__()

    self.mha1 = MultiHeadAttention(d_model, num_heads)
    self.mha2 = MultiHeadAttention(d_model, num_heads)

    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    self.dropout3 = tf.keras.layers.Dropout(rate)


  def call(self, x, enc_output, training,
           look_ahead_mask, padding_mask):
    # enc_output.shape == (batch_size, input_seq_len, d_model)

    attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
    attn1 = self.dropout1(attn1, training=training)
    out1 = self.layernorm1(attn1 + x)

    attn2, attn_weights_block2 = self.mha2(
        enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
    attn2 = self.dropout2(attn2, training=training)
    out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)

    ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
    ffn_output = self.dropout3(ffn_output, training=training)
    out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)

    return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Encoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers

    self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding,
                                            self.d_model)


    self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate)
                       for _ in range(num_layers)]

    self.dropout = tf.keras.layers.Dropout(rate)

  def call(self, x, training, mask):

    seq_len = tf.shape(x)[1]

    # adding embedding and position encoding.
    x = self.embedding(x)  # (batch_size, input_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x = self.enc_layers[i](x, training, mask)

    return x  # (batch_size, input_seq_len, d_model)

# %%
class Decoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Decoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers

    self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)

    self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate)
                       for _ in range(num_layers)]
    self.dropout = tf.keras.layers.Dropout(rate)

  def call(self, x, enc_output, training,
           look_ahead_mask, padding_mask):

    seq_len = tf.shape(x)[1]
    attention_weights = {}

    x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                             look_ahead_mask, padding_mask)

      attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
      attention_weights['decoder_layer{}_block2'.format(i+1)] = block2

    # x.shape == (batch_size, target_seq_len, d_model)
    return x, attention_weights

# %%
class Decoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Decoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers

    self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)

    self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate)
                       for _ in range(num_layers)]
    self.dropout = tf.keras.layers.Dropout(rate)

  def call(self, x, enc_output, training,
           look_ahead_mask, padding_mask):

    seq_len = tf.shape(x)[1]
    attention_weights = {}

    x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                             look_ahead_mask, padding_mask)

      attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
      attention_weights['decoder_layer{}_block2'.format(i+1)] = block2

    # x.shape == (batch_size, target_seq_len, d_model)
    return x, attention_weights

# %% [markdown]
# transf

# %%
class Transformer(tf.keras.Model):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
               target_vocab_size, pe_input, pe_target, rate=0.1):
    super(Transformer, self).__init__()

    self.encoder = Encoder(num_layers, d_model, num_heads, dff,
                           input_vocab_size, pe_input, rate)

    self.decoder = Decoder(num_layers, d_model, num_heads, dff,
                           target_vocab_size, pe_target, rate)

    self.final_layer = tf.keras.layers.Dense(target_vocab_size)

  def call(self, inp, tar, training, enc_padding_mask,
           look_ahead_mask, dec_padding_mask):

    enc_output = self.encoder(inp, training, enc_padding_mask)  # (batch_size, inp_seq_len, d_model)

    # dec_output.shape == (batch_size, tar_seq_len, d_model)
    dec_output, attention_weights = self.decoder(
        tar, enc_output, training, look_ahead_mask, dec_padding_mask)

    final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)

    return final_output, attention_weights

# %%
num_layers = 4
d_model = 128
dff = 512
num_heads = 8

input_vocab_size = tokenizer_pt.vocab_size + 2
target_vocab_size = tokenizer_en.vocab_size + 2
dropout_rate = 0.1

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')


def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_sum(loss_)/tf.reduce_sum(mask)


def accuracy_function(real, pred):
  accuracies = tf.equal(real, tf.argmax(pred, axis=2))

  mask = tf.math.logical_not(tf.math.equal(real, 0))
  accuracies = tf.math.logical_and(mask, accuracies)

  accuracies = tf.cast(accuracies, dtype=tf.float32)
  mask = tf.cast(mask, dtype=tf.float32)
  return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# %%
transformer = Transformer(num_layers, d_model, num_heads, dff,
                          input_vocab_size, target_vocab_size,
                          pe_input=input_vocab_size,
                          pe_target=target_vocab_size,
                          rate=dropout_rate)

# %%
def create_masks(inp, tar):
  # Encoder padding mask
  enc_padding_mask = create_padding_mask(inp)

  # Used in the 2nd attention block in the decoder.
  # This padding mask is used to mask the encoder outputs.
  dec_padding_mask = create_padding_mask(inp)

  # Used in the 1st attention block in the decoder.
  # It is used to pad and mask future tokens in the input received by
  # the decoder.
  look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
  dec_target_padding_mask = create_padding_mask(tar)
  combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)

  return enc_padding_mask, combined_mask, dec_padding_mask

# %%
checkpoint_path = "./checkpoints/train"

ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
  ckpt.restore(ckpt_manager.latest_checkpoint)
  print ('Latest checkpoint restored!!')

# %% [markdown]
# train

# %%
# The @tf.function trace-compiles train_step into a TF graph for faster
# execution. The function specializes to the precise shape of the argument
# tensors. To avoid re-tracing due to the variable sequence lengths or variable
# batch sizes (the last batch is smaller), use input_signature to specify
# more generic shapes.

train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
]

@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
  tar_inp = tar[:, :-1]
  tar_real = tar[:, 1:]

  enc_padding_mask, combined_mask, dec_padding_mask = create_masks(inp, tar_inp)

  with tf.GradientTape() as tape:
    predictions, _ = transformer(inp, tar_inp,
                                 True,
                                 enc_padding_mask,
                                 combined_mask,
                                 dec_padding_mask)
    loss = loss_function(tar_real, predictions)

  gradients = tape.gradient(loss, transformer.trainable_variables)
  optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

  train_loss(loss)
  train_accuracy(accuracy_function(tar_real, predictions))

# %%
EPOCHS = 20
for epoch in range(EPOCHS):
  start = time.time()

  train_loss.reset_states()
  train_accuracy.reset_states()

  # inp -> portuguese, tar -> english
  for (batch, (inp, tar)) in enumerate(train_dataset):
    train_step(inp, tar)

    if batch % 50 == 0:
      print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
          epoch + 1, batch, train_loss.result(), train_accuracy.result()))

  if (epoch + 1) % 5 == 0:
    ckpt_save_path = ckpt_manager.save()
    print ('Saving checkpoint for epoch {} at {}'.format(epoch+1,
                                                         ckpt_save_path))

  print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1,
                                                train_loss.result(),
                                                train_accuracy.result()))

  print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 9.0349 Accuracy 0.0000
# Epoch 1 Batch 50 Loss 7.1595 Accuracy 0.0531
# Epoch 1 Batch 100 Loss 6.8258 Accuracy 0.0535
# Epoch 1 Batch 150 Loss 6.7151 Accuracy 0.0545
# Epoch 1 Batch 200 Loss 6.6549 Accuracy 0.0541
# Epoch 1 Batch 250 Loss 6.6122 Accuracy 0.0538
# Epoch 1 Batch 300 Loss 6.5770 Accuracy 0.0586
# Epoch 1 Batch 350 Loss 6.5447 Accuracy 0.0640
# Epoch 1 Batch 400 Loss 6.5141 Accuracy 0.0684
# Epoch 1 Batch 450 Loss 6.4913 Accuracy 0.0719
# Epoch 1 Batch 500 Loss 6.4731 Accuracy 0.0745
# Epoch 1 Batch 550 Loss 6.4559 Accuracy 0.0767
# Epoch 1 Batch 600 Loss 6.4406 Accuracy 0.0785
# Epoch 1 Batch 650 Loss 6.4288 Accuracy 0.0798
# Epoch 1 Batch 700 Loss 6.4165 Accuracy 0.0812
# Epoch 1 Batch 750 Loss 6.4063 Accuracy 0.0823
# Epoch 1 Batch 800 Loss 6.3979 Accuracy 0.0833
# Epoch 1 Batch 850 Loss 6.3962 Accuracy 0.0833
# Epoch 1 Batch 900 Loss 6.3926 Accuracy 0.0838
# Epoch 1 Batch 950 Loss 6.3864 Accuracy 0.0844
# Epoch 1 Batch 1000 Loss 6.3804 Accuracy 0.0850
# Epoch 1 Batch 1050 Loss 6.3747 Accuracy 0.0857
# Epoch 1 Batch 1100 Loss 6.3690 Accuracy 0.0863
# Epoch 1 Batch 1150 Loss 6.3642 Accuracy 0.0868
# Epoch 1 Batch 1200 Loss 6.3590 Accuracy 0.0873
# Epoch 2 Batch 750 Loss 6.0819 Accuracy 0.1263
# Epoch 2 Batch 800 Loss 6.0799 Accuracy 0.1264
# Epoch 2 Batch 850 Loss 6.0803 Accuracy 0.1264
# Epoch 2 Batch 900 Loss 6.0802 Accuracy 0.1265
# Epoch 2 Batch 950 Loss 6.0800 Accuracy 0.1265
# Epoch 2 Batch 1000 Loss 6.0788 Accuracy 0.1265
# Epoch 2 Batch 1050 Loss 6.0782 Accuracy 0.1267
# Epoch 2 Batch 1100 Loss 6.0782 Accuracy 0.1267
# Epoch 2 Batch 1150 Loss 6.0778 Accuracy 0.1268
# Epoch 2 Batch 1200 Loss 6.0780 Accuracy 0.1267
# Epoch 2 Batch 1250 Loss 6.0780 Accuracy 0.1267
# Epoch 2 Batch 1300 Loss 6.0777 Accuracy 0.1268
# Epoch 2 Batch 1350 Loss 6.0780 Accuracy 0.1269
# Epoch 2 Batch 1400 Loss 6.0781 Accuracy 0.1269
# Epoch 2 Batch 1450 Loss 6.0781 Accuracy 0.1270
# Epoch 2 Batch 1500 Loss 6.0783 Accuracy 0.1271
# Epoch 2 Batch 1550 Loss 6.0786 Accuracy 0.1271
# Epoch 2 Batch 1600 Loss 6.0789 Accuracy 0.1271
# Epoch 2 Batch 1650 Loss 6.0790 Accuracy 0.1272
# Epoch 2 Batch 1700 Loss 6.0792 Accuracy 0.1273
# Epoch 2 Batch 1750 Loss 6.0798 Accuracy 0.1273
# Epoch 2 Batch 1800 Loss 6.0798 Accuracy 0.1274
# Epoch 2 Batch 1850 Loss 6.0804 Accuracy 0.1275
# Epoch 2 Batch 1900 Loss 6.0806 Accuracy 0.1275
# Epoch 2 Batch 1950 Loss 6.0811 Accuracy 0.1275
# Epoch 2 Batch 2000 Loss 6.0814 Accuracy 0.1276
# Epoch 2 Batch 2050 Loss 6.0818 Accuracy 0.1276
# Epoch 2 Batch 2100 Loss 6.0822 Accuracy 0.1277
# Epoch 2 Batch 2150 Loss 6.0822 Accuracy 0.1277
# Epoch 2 Batch 2200 Loss 6.0824 Accuracy 0.1277
# Epoch 2 Batch 2250 Loss 6.0820 Accuracy 0.1278
# Epoch 2 Batch 2300 Loss 6.0822 Accuracy 0.1278
# Epoch 2 Batch 2350 Loss 6.0821 Accuracy 0.1279
# Epoch 2 Batch 2400 Loss 6.0820 Accuracy 0.1279
# Epoch 2 Batch 2450 Loss 6.0814 Accuracy 0.1280
# Epoch 2 Batch 2500 Loss 6.0816 Accuracy 0.1280
# Epoch 2 Batch 2550 Loss 6.0817 Accuracy 0.1280
# Epoch 2 Batch 2600 Loss 6.0818 Accuracy 0.1280
# Epoch 2 Loss 6.0817 Accuracy 0.1281
# Time taken for 1 epoch: 171.58570313453674 secs
#
# Epoch 3 Batch 0 Loss 6.1168 Accuracy 0.1345
# Epoch 3 Batch 50 Loss 6.0471 Accuracy 0.1308
# Epoch 3 Batch 100 Loss 6.0592 Accuracy 0.1308
# Epoch 3 Batch 150 Loss 6.0596 Accuracy 0.1311
# Epoch 3 Batch 200 Loss 6.0632 Accuracy 0.1310
# Epoch 3 Batch 250 Loss 6.0658 Accuracy 0.1302
# Epoch 3 Batch 300 Loss 6.0667 Accuracy 0.1304
# Epoch 3 Batch 350 Loss 6.0669 Accuracy 0.1302
# Epoch 3 Batch 400 Loss 6.0676 Accuracy 0.1304
# Epoch 3 Batch 450 Loss 6.0703 Accuracy 0.1303
# Epoch 3 Batch 500 Loss 6.0697 Accuracy 0.1306
# Epoch 3 Batch 550 Loss 6.0687 Accuracy 0.1306
# Epoch 3 Batch 600 Loss 6.0696 Accuracy 0.1304
# Epoch 3 Batch 650 Loss 6.0678 Accuracy 0.1306
# Epoch 3 Batch 700 Loss 6.0687 Accuracy 0.1306
# Epoch 3 Batch 750 Loss 6.0694 Accuracy 0.1306
# Epoch 3 Batch 800 Loss 6.0687 Accuracy 0.1307
# Epoch 3 Batch 850 Loss 6.0696 Accuracy 0.1306
# Epoch 3 Batch 900 Loss 6.0710 Accuracy 0.1306
# Epoch 3 Batch 950 Loss 6.0720 Accuracy 0.1306
# Epoch 3 Batch 1000 Loss 6.0707 Accuracy 0.1307
# Epoch 3 Batch 1050 Loss 6.0725 Accuracy 0.1306
# Epoch 3 Batch 1100 Loss 6.0732 Accuracy 0.1305
# Epoch 3 Batch 1150 Loss 6.0745 Accuracy 0.1305
# Epoch 3 Batch 1200 Loss 6.0757 Accuracy 0.1305
# Epoch 3 Batch 1250 Loss 6.0767 Accuracy 0.1304
# Epoch 3 Batch 1300 Loss 6.0766 Accuracy 0.1304
# Epoch 3 Batch 1350 Loss 6.0772 Accuracy 0.1304
# Epoch 3 Batch 1400 Loss 6.0764 Accuracy 0.1305
# Epoch 3 Batch 1450 Loss 6.0764 Accuracy 0.1305
# Epoch 3 Batch 1500 Loss 6.0758 Accuracy 0.1306
# Epoch 3 Batch 1550 Loss 6.0756 Accuracy 0.1306
# Epoch 3 Batch 1600 Loss 6.0756 Accuracy 0.1305
# Epoch 3 Batch 1650 Loss 6.0757 Accuracy 0.1305
# Epoch 3 Batch 1700 Loss 6.0764 Accuracy 0.1305
# Epoch 3 Batch 1750 Loss 6.0762 Accuracy 0.1305
# Epoch 3 Batch 1800 Loss 6.0751 Accuracy 0.1306
# Epoch 3 Batch 1850 Loss 6.0754 Accuracy 0.1306
# Epoch 3 Batch 1900 Loss 6.0753 Accuracy 0.1306
# Epoch 3 Batch 1950 Loss 6.0754 Accuracy 0.1306
# Epoch 3 Batch 2000 Loss 6.0754 Accuracy 0.1307
# Epoch 3 Batch 2050 Loss 6.0754 Accuracy 0.1307
# Epoch 3 Batch 2100 Loss 6.0752 Accuracy 0.1307
# Epoch 3 Batch 2150 Loss 6.0749 Accuracy 0.1307
# Epoch 3 Batch 2200 Loss 6.0752 Accuracy 0.1307
# Epoch 3 Batch 2250 Loss 6.0749 Accuracy 0.1307
# Epoch 3 Batch 2300 Loss 6.0745 Accuracy 0.1308
# Epoch 3 Batch 2350 Loss 6.0748 Accuracy 0.1307
# Epoch 3 Batch 2400 Loss 6.0749 Accuracy 0.1307
# Epoch 3 Batch 2450 Loss 6.0746 Accuracy 0.1308
# Epoch 3 Batch 2500 Loss 6.0740 Accuracy 0.1308
# Epoch 3 Batch 2550 Loss 6.0739 Accuracy 0.1308
# Epoch 3 Batch 2600 Loss 6.0742 Accuracy 0.1308
# Epoch 3 Loss 6.0742 Accuracy 0.1309
# Time taken for 1 epoch: 171.17852234840393 secs
#
# Epoch 4 Batch 0 Loss 5.9074 Accuracy 0.1308
# Epoch 4 Batch 50 Loss 6.0701 Accuracy 0.1315
# Epoch 4 Batch 100 Loss 6.0695 Accuracy 0.1325
# Epoch 4 Batch 150 Loss 6.0673 Accuracy 0.1327
# Epoch 4 Batch 200 Loss 6.0677 Accuracy 0.1326
# Epoch 4 Batch 250 Loss 6.0659 Accuracy 0.1326
# Epoch 4 Batch 300 Loss 6.0641 Accuracy 0.1330
# Epoch 4 Batch 350 Loss 6.0645 Accuracy 0.1330
# Epoch 4 Batch 400 Loss 6.0656 Accuracy 0.1329
# Epoch 4 Batch 450 Loss 6.1353 Accuracy 0.1288
# Epoch 4 Batch 500 Loss 6.1728 Accuracy 0.1206
# Epoch 4 Batch 550 Loss 6.1983 Accuracy 0.1145
# Epoch 4 Batch 600 Loss 6.2154 Accuracy 0.1102
# Epoch 4 Batch 650 Loss 6.2236 Accuracy 0.1070
# Epoch 4 Batch 700 Loss 6.2299 Accuracy 0.1047
# Epoch 4 Batch 750 Loss 6.2334 Accuracy 0.1029
# Epoch 4 Batch 800 Loss 6.2381 Accuracy 0.1014
# Epoch 4 Batch 850 Loss 6.2400 Accuracy 0.1000
# Epoch 4 Batch 900 Loss 6.2425 Accuracy 0.0989
# Epoch 4 Batch 950 Loss 6.2432 Accuracy 0.0981
# Epoch 4 Batch 1000 Loss 6.2445 Accuracy 0.0973
# Epoch 4 Batch 1050 Loss 6.2458 Accuracy 0.0965
# Epoch 4 Batch 1100 Loss 6.2464 Accuracy 0.0959
# Epoch 4 Batch 1150 Loss 6.2461 Accuracy 0.0954
# Epoch 4 Batch 1200 Loss 6.2460 Accuracy 0.0950
# Epoch 4 Batch 1250 Loss 6.2458 Accuracy 0.0946
# Epoch 4 Batch 1300 Loss 6.2456 Accuracy 0.0942
# Epoch 4 Batch 1350 Loss 6.2457 Accuracy 0.0940
# Epoch 4 Batch 1400 Loss 6.2457 Accuracy 0.0937
# Epoch 4 Batch 1450 Loss 6.2452 Accuracy 0.0934
# Epoch 4 Batch 1500 Loss 6.2451 Accuracy 0.0932
# Epoch 4 Batch 1550 Loss 6.2449 Accuracy 0.0931
# Epoch 4 Batch 1600 Loss 6.2443 Accuracy 0.0929
# Epoch 4 Batch 1650 Loss 6.2434 Accuracy 0.0927
# Epoch 4 Batch 1700 Loss 6.2432 Accuracy 0.0926
# Epoch 4 Batch 1750 Loss 6.2434 Accuracy 0.0924
# Epoch 4 Batch 1800 Loss 6.2433 Accuracy 0.0923
# Epoch 4 Batch 1850 Loss 6.2424 Accuracy 0.0922
# Epoch 4 Batch 1900 Loss 6.2419 Accuracy 0.0921
# Epoch 4 Batch 1950 Loss 6.2414 Accuracy 0.0921
# Epoch 4 Batch 2000 Loss 6.2416 Accuracy 0.0919
# Epoch 6 Batch 1100 Loss 6.2106 Accuracy 0.0896
# Epoch 6 Batch 1150 Loss 6.2115 Accuracy 0.0894
# Epoch 6 Batch 1200 Loss 6.2125 Accuracy 0.0894
# Epoch 6 Batch 1250 Loss 6.2134 Accuracy 0.0893
# Epoch 6 Batch 1300 Loss 6.2142 Accuracy 0.0894
# Epoch 6 Batch 1350 Loss 6.2155 Accuracy 0.0893
# Epoch 6 Batch 1400 Loss 6.2161 Accuracy 0.0894
# Epoch 6 Batch 1450 Loss 6.2166 Accuracy 0.0894
# Epoch 6 Batch 1500 Loss 6.2172 Accuracy 0.0894
# Epoch 6 Batch 1550 Loss 6.2175 Accuracy 0.0894
# Epoch 6 Batch 1600 Loss 6.2183 Accuracy 0.0893
# Epoch 6 Batch 1650 Loss 6.2182 Accuracy 0.0894
# Epoch 6 Batch 1700 Loss 6.2188 Accuracy 0.0894
# Epoch 6 Batch 1750 Loss 6.2193 Accuracy 0.0894
# Epoch 6 Batch 1800 Loss 6.2199 Accuracy 0.0895
# Epoch 6 Batch 1850 Loss 6.2201 Accuracy 0.0895
# Epoch 6 Batch 1900 Loss 6.2204 Accuracy 0.0896
# Epoch 6 Batch 1950 Loss 6.2203 Accuracy 0.0896
# Epoch 6 Batch 2000 Loss 6.2202 Accuracy 0.0896
# Epoch 6 Batch 2050 Loss 6.2210 Accuracy 0.0896
# Epoch 6 Batch 2100 Loss 6.2207 Accuracy 0.0897
# Epoch 6 Batch 2150 Loss 6.2205 Accuracy 0.0897
# Epoch 6 Batch 2200 Loss 6.2208 Accuracy 0.0897
# Epoch 6 Batch 2250 Loss 6.2204 Accuracy 0.0897
# Epoch 6 Batch 2300 Loss 6.2202 Accuracy 0.0898
# Epoch 6 Batch 2350 Loss 6.2202 Accuracy 0.0898
# Epoch 6 Batch 2400 Loss 6.2198 Accuracy 0.0898
# Epoch 6 Batch 2450 Loss 6.2192 Accuracy 0.0899
# Epoch 6 Batch 2500 Loss 6.2191 Accuracy 0.0899
# Epoch 6 Batch 2550 Loss 6.2191 Accuracy 0.0899
# Epoch 6 Batch 2600 Loss 6.2199 Accuracy 0.0898
# Epoch 6 Loss 6.2196 Accuracy 0.0898
# Time taken for 1 epoch: 171.5880799293518 secs
#
# Epoch 7 Batch 0 Loss 6.2785 Accuracy 0.0932
# Epoch 7 Batch 50 Loss 6.2393 Accuracy 0.0873
# Epoch 7 Batch 100 Loss 6.2228 Accuracy 0.0878
# Epoch 7 Batch 150 Loss 6.2172 Accuracy 0.0882
# Epoch 7 Batch 200 Loss 6.2134 Accuracy 0.0889
# Epoch 7 Batch 250 Loss 6.2079 Accuracy 0.0902
# Epoch 7 Batch 300 Loss 6.2037 Accuracy 0.0910
# Epoch 7 Batch 350 Loss 6.1947 Accuracy 0.0920
# Epoch 7 Batch 400 Loss 6.1923 Accuracy 0.0926
# Epoch 7 Batch 450 Loss 6.1904 Accuracy 0.0931
# Epoch 7 Batch 500 Loss 6.1846 Accuracy 0.0937
# Epoch 7 Batch 550 Loss 6.1816 Accuracy 0.0942
# Epoch 7 Batch 600 Loss 6.1772 Accuracy 0.0946
# Epoch 8 Batch 150 Loss 5.9842 Accuracy 0.1376
# Epoch 8 Batch 200 Loss 5.9795 Accuracy 0.1388
# Epoch 8 Batch 250 Loss 5.9721 Accuracy 0.1396
# Epoch 8 Batch 300 Loss 5.9665 Accuracy 0.1405
# Epoch 8 Batch 350 Loss 5.9572 Accuracy 0.1417
# Epoch 8 Batch 400 Loss 5.9633 Accuracy 0.1400
# Epoch 8 Batch 450 Loss 5.9644 Accuracy 0.1399
# Epoch 8 Batch 500 Loss 5.9775 Accuracy 0.1372
# Epoch 8 Batch 550 Loss 6.0030 Accuracy 0.1326
# Epoch 8 Batch 600 Loss 6.0240 Accuracy 0.1284
# Epoch 8 Batch 650 Loss 6.0407 Accuracy 0.1249
# Epoch 8 Batch 700 Loss 6.0543 Accuracy 0.1220
# Epoch 8 Batch 750 Loss 6.0650 Accuracy 0.1196
# Epoch 8 Batch 800 Loss 6.0744 Accuracy 0.1175
# Epoch 8 Batch 850 Loss 6.0815 Accuracy 0.1158
# Epoch 8 Batch 900 Loss 6.0858 Accuracy 0.1145
# Epoch 8 Batch 950 Loss 6.0896 Accuracy 0.1135
# Epoch 8 Batch 1000 Loss 6.0947 Accuracy 0.1129
# Epoch 8 Batch 1050 Loss 6.1039 Accuracy 0.1113
# Epoch 8 Batch 1100 Loss 6.1097 Accuracy 0.1103
# Epoch 8 Batch 1150 Loss 6.1142 Accuracy 0.1094
# Epoch 8 Batch 1200 Loss 6.1180 Accuracy 0.1086
# Epoch 8 Batch 1250 Loss 6.1218 Accuracy 0.1079
# Epoch 8 Batch 1300 Loss 6.1251 Accuracy 0.1072
# Epoch 8 Batch 1350 Loss 6.1262 Accuracy 0.1067
# Epoch 8 Batch 1400 Loss 6.1283 Accuracy 0.1061
# Epoch 8 Batch 1450 Loss 6.1302 Accuracy 0.1056
# Epoch 8 Batch 1500 Loss 6.1311 Accuracy 0.1052
# Epoch 8 Batch 1550 Loss 6.1320 Accuracy 0.1048
# Epoch 8 Batch 1600 Loss 6.1334 Accuracy 0.1044
# Epoch 8 Batch 1650 Loss 6.1348 Accuracy 0.1041
# Epoch 8 Batch 1700 Loss 6.1357 Accuracy 0.1037
# Epoch 8 Batch 1750 Loss 6.1368 Accuracy 0.1034
# Epoch 8 Batch 1800 Loss 6.1381 Accuracy 0.1031
# Epoch 8 Batch 1850 Loss 6.1389 Accuracy 0.1029
# Epoch 8 Batch 1900 Loss 6.1394 Accuracy 0.1026
# Epoch 8 Batch 1950 Loss 6.1399 Accuracy 0.1024
# Epoch 8 Batch 2000 Loss 6.1400 Accuracy 0.1021
# Epoch 8 Batch 2050 Loss 6.1407 Accuracy 0.1019
# Epoch 8 Batch 2100 Loss 6.1411 Accuracy 0.1017
# Epoch 8 Batch 2150 Loss 6.1417 Accuracy 0.1015
# Epoch 8 Batch 2200 Loss 6.1421 Accuracy 0.1013
# Epoch 8 Batch 2250 Loss 6.1422 Accuracy 0.1012
# Epoch 8 Batch 2300 Loss 6.1422 Accuracy 0.1011
# Epoch 8 Batch 2350 Loss 6.1415 Accuracy 0.1010
# Epoch 9 Batch 1900 Loss 6.0626 Accuracy 0.1047
# Epoch 9 Batch 1950 Loss 6.0618 Accuracy 0.1048
# Epoch 9 Batch 2000 Loss 6.0606 Accuracy 0.1049
# Epoch 9 Batch 2050 Loss 6.0593 Accuracy 0.1051
# Epoch 9 Batch 2100 Loss 6.0583 Accuracy 0.1053
# Epoch 9 Batch 2150 Loss 6.0572 Accuracy 0.1055
# Epoch 9 Batch 2200 Loss 6.0563 Accuracy 0.1056
# Epoch 9 Batch 2250 Loss 6.0547 Accuracy 0.1063
# Epoch 9 Batch 2300 Loss 6.0551 Accuracy 0.1061
# Epoch 9 Batch 2350 Loss 6.0543 Accuracy 0.1061
# Epoch 9 Batch 2400 Loss 6.0535 Accuracy 0.1062
# Epoch 9 Batch 2450 Loss 6.0522 Accuracy 0.1064
# Epoch 9 Batch 2500 Loss 6.0499 Accuracy 0.1070
# Epoch 9 Batch 2550 Loss 6.0469 Accuracy 0.1079
# Epoch 9 Batch 2600 Loss 6.0435 Accuracy 0.1088
# Epoch 9 Loss 6.0422 Accuracy 0.1092
# Time taken for 1 epoch: 167.7304117679596 secs
#
# Epoch 10 Batch 0 Loss 5.8791 Accuracy 0.1409
# Epoch 10 Batch 50 Loss 5.8521 Accuracy 0.1548
# Epoch 10 Batch 100 Loss 5.8820 Accuracy 0.1489
# Epoch 10 Batch 150 Loss 5.8922 Accuracy 0.1481
# Epoch 10 Batch 200 Loss 5.8900 Accuracy 0.1492
# Epoch 10 Batch 250 Loss 5.8857 Accuracy 0.1498
# Epoch 10 Batch 300 Loss 5.8792 Accuracy 0.1505
# Epoch 10 Batch 350 Loss 5.8747 Accuracy 0.1510
# Epoch 10 Batch 400 Loss 5.8750 Accuracy 0.1512
# Epoch 10 Batch 450 Loss 5.8715 Accuracy 0.1516
# Epoch 10 Batch 500 Loss 5.8697 Accuracy 0.1519
# Epoch 10 Batch 550 Loss 5.8661 Accuracy 0.1523
# Epoch 10 Batch 600 Loss 5.8650 Accuracy 0.1526
# Epoch 10 Batch 650 Loss 5.8642 Accuracy 0.1528
# Epoch 10 Batch 700 Loss 5.8625 Accuracy 0.1530
# Epoch 10 Batch 750 Loss 5.8632 Accuracy 0.1530
# Epoch 10 Batch 800 Loss 5.8634 Accuracy 0.1532
# Epoch 10 Batch 850 Loss 5.8630 Accuracy 0.1533
# Epoch 10 Batch 900 Loss 5.8619 Accuracy 0.1535
# Epoch 10 Batch 950 Loss 5.8597 Accuracy 0.1537
# Epoch 10 Batch 1000 Loss 5.8584 Accuracy 0.1538
# Epoch 10 Batch 1050 Loss 5.8564 Accuracy 0.1541
# Epoch 10 Batch 1100 Loss 5.8546 Accuracy 0.1542
# Epoch 10 Batch 1150 Loss 5.8556 Accuracy 0.1541
# Epoch 10 Batch 1200 Loss 5.8559 Accuracy 0.1540
# Epoch 10 Batch 1250 Loss 5.8565 Accuracy 0.1540
# Epoch 10 Batch 1300 Loss 5.8557 Accuracy 0.1541
# Epoch 10 Batch 1350 Loss 5.8560 Accuracy 0.1541
# Epoch 10 Batch 1400 Loss 5.8618 Accuracy 0.1532
# Epoch 12 Batch 450 Loss 5.6024 Accuracy 0.1712
# Epoch 12 Batch 500 Loss 5.5992 Accuracy 0.1714
# Epoch 12 Batch 550 Loss 5.5954 Accuracy 0.1718
# Epoch 12 Batch 600 Loss 5.5945 Accuracy 0.1719
# Epoch 12 Batch 650 Loss 5.5920 Accuracy 0.1723
# Epoch 12 Batch 700 Loss 5.5904 Accuracy 0.1725
# Epoch 12 Batch 750 Loss 5.5874 Accuracy 0.1728
# Epoch 12 Batch 800 Loss 5.5859 Accuracy 0.1729
# Epoch 12 Batch 850 Loss 5.5841 Accuracy 0.1731
# Epoch 12 Batch 900 Loss 5.5828 Accuracy 0.1732
# Epoch 12 Batch 950 Loss 5.5805 Accuracy 0.1734
# Epoch 12 Batch 1000 Loss 5.5793 Accuracy 0.1735
# Epoch 12 Batch 1050 Loss 5.5766 Accuracy 0.1737
# Epoch 12 Batch 1100 Loss 5.5757 Accuracy 0.1738
# Epoch 12 Batch 1150 Loss 5.5749 Accuracy 0.1740
# Epoch 12 Batch 1200 Loss 5.5724 Accuracy 0.1740
# Epoch 12 Batch 1250 Loss 5.5718 Accuracy 0.1741
# Epoch 12 Batch 1300 Loss 5.5700 Accuracy 0.1743
# Epoch 12 Batch 1350 Loss 5.5677 Accuracy 0.1745
# Epoch 12 Batch 1400 Loss 5.5667 Accuracy 0.1745
# Epoch 12 Batch 1450 Loss 5.5655 Accuracy 0.1746
# Epoch 12 Batch 1500 Loss 5.5651 Accuracy 0.1746
# Epoch 12 Batch 1550 Loss 5.5640 Accuracy 0.1746
# Epoch 12 Batch 1600 Loss 5.5627 Accuracy 0.1747
# Epoch 12 Batch 1650 Loss 5.5615 Accuracy 0.1748
# Epoch 12 Batch 1700 Loss 5.5599 Accuracy 0.1749
# Epoch 12 Batch 1750 Loss 5.5590 Accuracy 0.1750
# Epoch 12 Batch 1800 Loss 5.5585 Accuracy 0.1750
# Epoch 12 Batch 1850 Loss 5.5566 Accuracy 0.1752
# Epoch 12 Batch 1900 Loss 5.5555 Accuracy 0.1753
# Epoch 12 Batch 1950 Loss 5.5536 Accuracy 0.1755
# Epoch 12 Batch 2000 Loss 5.5517 Accuracy 0.1757
# Epoch 12 Batch 2050 Loss 5.5506 Accuracy 0.1757
# Epoch 12 Batch 2100 Loss 5.5494 Accuracy 0.1759
# Epoch 12 Batch 2150 Loss 5.5479 Accuracy 0.1760
# Epoch 12 Batch 2200 Loss 5.5463 Accuracy 0.1762
# Epoch 12 Batch 2250 Loss 5.5451 Accuracy 0.1763
# Epoch 12 Batch 2300 Loss 5.5436 Accuracy 0.1764
# Epoch 12 Batch 2350 Loss 5.5429 Accuracy 0.1765
# Epoch 12 Batch 2400 Loss 5.5420 Accuracy 0.1765
# Epoch 12 Batch 2450 Loss 5.5410 Accuracy 0.1766
# Epoch 12 Batch 2500 Loss 5.5397 Accuracy 0.1767
# Epoch 12 Batch 2550 Loss 5.5386 Accuracy 0.1768
# Epoch 12 Batch 2600 Loss 5.5374 Accuracy 0.1769
# Epoch 12 Loss 5.5370 Accuracy 0.1770
# Time taken for 1 epoch: 166.63670301437378 secs
# Epoch 14 Batch 1750 Loss 5.4389 Accuracy 0.1860
# Epoch 14 Batch 1800 Loss 5.4382 Accuracy 0.1861
# Epoch 14 Batch 1850 Loss 5.4374 Accuracy 0.1862
# Epoch 14 Batch 1900 Loss 5.4364 Accuracy 0.1863
# Epoch 14 Batch 1950 Loss 5.4351 Accuracy 0.1864
# Epoch 14 Batch 2000 Loss 5.4342 Accuracy 0.1865
# Epoch 14 Batch 2050 Loss 5.4328 Accuracy 0.1867
# Epoch 14 Batch 2100 Loss 5.4310 Accuracy 0.1869
# Epoch 14 Batch 2150 Loss 5.4293 Accuracy 0.1872
# Epoch 14 Batch 2200 Loss 5.4282 Accuracy 0.1873
# Epoch 14 Batch 2250 Loss 5.4277 Accuracy 0.1873
# Epoch 14 Batch 2300 Loss 5.4267 Accuracy 0.1875
# Epoch 14 Batch 2350 Loss 5.4251 Accuracy 0.1877
# Epoch 14 Batch 2400 Loss 5.4241 Accuracy 0.1878
# Epoch 14 Batch 2450 Loss 5.4232 Accuracy 0.1879
# Epoch 14 Batch 2500 Loss 5.4219 Accuracy 0.1881
# Epoch 14 Batch 2550 Loss 5.4206 Accuracy 0.1883
# Epoch 14 Batch 2600 Loss 5.4192 Accuracy 0.1884
# Epoch 14 Loss 5.4186 Accuracy 0.1885
# Time taken for 1 epoch: 167.85564064979553 secs
#
# Epoch 15 Batch 0 Loss 5.3091 Accuracy 0.2089
# Epoch 15 Batch 50 Loss 5.3312 Accuracy 0.1971
# Epoch 15 Batch 100 Loss 5.3220 Accuracy 0.1983
# Epoch 15 Batch 150 Loss 5.3231 Accuracy 0.1982
# Epoch 15 Batch 200 Loss 5.3266 Accuracy 0.1982
# Epoch 15 Batch 250 Loss 5.3314 Accuracy 0.1979
# Epoch 15 Batch 300 Loss 5.3267 Accuracy 0.1983
# Epoch 15 Batch 350 Loss 5.3271 Accuracy 0.1983
# Epoch 15 Batch 400 Loss 5.3243 Accuracy 0.1990
# Epoch 15 Batch 450 Loss 5.3200 Accuracy 0.1995
# Epoch 15 Batch 500 Loss 5.3188 Accuracy 0.1998
# Epoch 15 Batch 550 Loss 5.3210 Accuracy 0.1998
# Epoch 15 Batch 600 Loss 5.3180 Accuracy 0.2001
# Epoch 15 Batch 650 Loss 5.3145 Accuracy 0.2004
# Epoch 15 Batch 700 Loss 5.3137 Accuracy 0.2006
# Epoch 15 Batch 750 Loss 5.3144 Accuracy 0.2005
# Epoch 15 Batch 800 Loss 5.3136 Accuracy 0.2007
# Epoch 15 Batch 850 Loss 5.3159 Accuracy 0.2004
# Epoch 15 Batch 900 Loss 5.3143 Accuracy 0.2006
# Epoch 15 Batch 950 Loss 5.3140 Accuracy 0.2007
# Epoch 15 Batch 1000 Loss 5.3113 Accuracy 0.2010
# Epoch 15 Batch 1050 Loss 5.3103 Accuracy 0.2011
# Epoch 15 Batch 1100 Loss 5.3101 Accuracy 0.2011
# Epoch 15 Batch 1150 Loss 5.3092 Accuracy 0.2012
# Epoch 15 Batch 1200 Loss 5.3081 Accuracy 0.2013
# Epoch 15 Batch 1250 Loss 5.3060 Accuracy 0.2016
# Epoch 19 Batch 1600 Loss 4.9919 Accuracy 0.2288
# Epoch 19 Batch 1650 Loss 4.9918 Accuracy 0.2287
# Epoch 19 Batch 1700 Loss 4.9918 Accuracy 0.2287
# Epoch 19 Batch 1750 Loss 4.9922 Accuracy 0.2287
# Epoch 19 Batch 1800 Loss 4.9917 Accuracy 0.2287
# Epoch 19 Batch 1850 Loss 4.9913 Accuracy 0.2288
# Epoch 19 Batch 1900 Loss 4.9909 Accuracy 0.2288
# Epoch 19 Batch 1950 Loss 4.9900 Accuracy 0.2288
# Epoch 19 Batch 2000 Loss 4.9898 Accuracy 0.2288
# Epoch 19 Batch 2050 Loss 4.9893 Accuracy 0.2289
# Epoch 19 Batch 2100 Loss 4.9888 Accuracy 0.2290
# Epoch 19 Batch 2150 Loss 4.9888 Accuracy 0.2289
# Epoch 19 Batch 2200 Loss 4.9890 Accuracy 0.2289
# Epoch 19 Batch 2250 Loss 4.9885 Accuracy 0.2289
# Epoch 19 Batch 2300 Loss 4.9890 Accuracy 0.2289
# Epoch 19 Batch 2350 Loss 4.9890 Accuracy 0.2289
# Epoch 19 Batch 2400 Loss 4.9888 Accuracy 0.2290
# Epoch 19 Batch 2450 Loss 4.9892 Accuracy 0.2289
# Epoch 19 Batch 2500 Loss 4.9895 Accuracy 0.2289
# Epoch 19 Batch 2550 Loss 4.9891 Accuracy 0.2289
# Epoch 19 Batch 2600 Loss 4.9892 Accuracy 0.2289
# Epoch 19 Loss 4.9894 Accuracy 0.2289
# Time taken for 1 epoch: 169.3392117023468 secs
#
# Epoch 20 Batch 0 Loss 4.8122 Accuracy 0.2484
# Epoch 20 Batch 50 Loss 4.9840 Accuracy 0.2283
# Epoch 20 Batch 100 Loss 4.9593 Accuracy 0.2304
# Epoch 20 Batch 150 Loss 4.9504 Accuracy 0.2316
# Epoch 20 Batch 200 Loss 4.9532 Accuracy 0.2318
# Epoch 20 Batch 250 Loss 4.9521 Accuracy 0.2322
# Epoch 20 Batch 300 Loss 4.9570 Accuracy 0.2319
# Epoch 20 Batch 350 Loss 4.9625 Accuracy 0.2309
# Epoch 20 Batch 400 Loss 4.9640 Accuracy 0.2307
# Epoch 20 Batch 450 Loss 4.9668 Accuracy 0.2303
# Epoch 20 Batch 500 Loss 4.9654 Accuracy 0.2306
# Epoch 20 Batch 550 Loss 4.9659 Accuracy 0.2305
# Epoch 20 Batch 600 Loss 4.9661 Accuracy 0.2305
# Epoch 20 Batch 650 Loss 4.9666 Accuracy 0.2303
# Epoch 20 Batch 700 Loss 4.9660 Accuracy 0.2302
# Epoch 20 Batch 750 Loss 4.9651 Accuracy 0.2303
# Epoch 20 Batch 800 Loss 4.9635 Accuracy 0.2304
# Epoch 20 Batch 850 Loss 4.9605 Accuracy 0.2307
# Epoch 20 Batch 900 Loss 4.9590 Accuracy 0.2309
# Epoch 20 Batch 950 Loss 4.9599 Accuracy 0.2309
# Epoch 20 Batch 1000 Loss 4.9596 Accuracy 0.2310
# Epoch 20 Batch 1050 Loss 4.9601 Accuracy 0.2310
# Epoch 20 Batch 1100 Loss 4.9598 Accuracy 0.2310
# Epoch 20 Batch 1150 Loss 4.9587 Accuracy 0.2311
# Epoch 20 Batch 1200 Loss 4.9575 Accuracy 0.2312
# Epoch 20 Batch 1250 Loss 4.9593 Accuracy 0.2310
# Epoch 20 Batch 1300 Loss 4.9608 Accuracy 0.2307
# Epoch 20 Batch 1350 Loss 4.9610 Accuracy 0.2306
# Epoch 20 Batch 1400 Loss 4.9612 Accuracy 0.2307
# Epoch 20 Batch 1450 Loss 4.9612 Accuracy 0.2307
# Epoch 20 Batch 1500 Loss 4.9611 Accuracy 0.2307
# Epoch 20 Batch 1550 Loss 4.9613 Accuracy 0.2307
# Epoch 20 Batch 1600 Loss 4.9608 Accuracy 0.2307
# Epoch 20 Batch 1650 Loss 4.9603 Accuracy 0.2309
# Epoch 20 Batch 1700 Loss 4.9599 Accuracy 0.2310
# Epoch 20 Batch 1750 Loss 4.9594 Accuracy 0.2309
# Epoch 20 Batch 1800 Loss 4.9591 Accuracy 0.2310
# Epoch 20 Batch 1850 Loss 4.9593 Accuracy 0.2311
# Epoch 20 Batch 1900 Loss 4.9589 Accuracy 0.2311
# Epoch 20 Batch 1950 Loss 4.9580 Accuracy 0.2312
# Epoch 20 Batch 2000 Loss 4.9571 Accuracy 0.2313
# Epoch 20 Batch 2050 Loss 4.9575 Accuracy 0.2313
# Epoch 20 Batch 2100 Loss 4.9571 Accuracy 0.2314
# Epoch 20 Batch 2150 Loss 4.9570 Accuracy 0.2314
# Epoch 20 Batch 2200 Loss 4.9568 Accuracy 0.2315
# Epoch 20 Batch 2250 Loss 4.9567 Accuracy 0.2315
# Epoch 20 Batch 2300 Loss 4.9562 Accuracy 0.2315
# Epoch 20 Batch 2350 Loss 4.9556 Accuracy 0.2316
# Epoch 20 Batch 2400 Loss 4.9552 Accuracy 0.2316
# Epoch 20 Batch 2450 Loss 4.9549 Accuracy 0.2317
# Epoch 20 Batch 2500 Loss 4.9542 Accuracy 0.2317
# Epoch 20 Batch 2550 Loss 4.9543 Accuracy 0.2317
# Epoch 20 Batch 2600 Loss 4.9537 Accuracy 0.2317
# Saving checkpoint for epoch 20 at ./checkpoints/train/ckpt-4
# Epoch 20 Loss 4.9535 Accuracy 0.2318
# Time taken for 1 epoch: 166.65373969078064 secs

# %% [markdown]
# evaluate

# %%
def evaluate(inp_sentence):
  start_token = [tokenizer_pt.vocab_size]
  end_token = [tokenizer_pt.vocab_size + 1]

  # inp sentence is portuguese, hence adding the start and end token
  inp_sentence = start_token + tokenizer_pt.encode(inp_sentence) + end_token
  encoder_input = tf.expand_dims(inp_sentence, 0)

  # as the target is english, the first word to the transformer should be the
  # english start token.
  decoder_input = [tokenizer_en.vocab_size]
  output = tf.expand_dims(decoder_input, 0)

  for i in range(MAX_LENGTH):
    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(
        encoder_input, output)

    # predictions.shape == (batch_size, seq_len, vocab_size)
    predictions, attention_weights = transformer(encoder_input,
                                                 output,
                                                 False,
                                                 enc_padding_mask,
                                                 combined_mask,
                                                 dec_padding_mask)

    # select the last word from the seq_len dimension
    predictions = predictions[: ,-1:, :]  # (batch_size, 1, vocab_size)

    predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

    # return the result if the predicted_id is equal to the end token
    if predicted_id == tokenizer_en.vocab_size+1:
      return tf.squeeze(output, axis=0), attention_weights

    # concatentate the predicted_id to the output which is given to the decoder
    # as its input.
    output = tf.concat([output, predicted_id], axis=-1)

  return tf.squeeze(output, axis=0), attention_weights

# %%
def plot_attention_weights(attention, sentence, result, layer):
  fig = plt.figure(figsize=(16, 8))

  sentence = tokenizer_pt.encode(sentence)

  attention = tf.squeeze(attention[layer], axis=0)

  for head in range(attention.shape[0]):
    ax = fig.add_subplot(2, 4, head+1)

    # plot the attention weights
    ax.matshow(attention[head][:-1, :], cmap='viridis')

    fontdict = {'fontsize': 10}

    ax.set_xticks(range(len(sentence)+2))
    ax.set_yticks(range(len(result)))

    ax.set_ylim(len(result)-1.5, -0.5)

    ax.set_xticklabels(
        ['<start>']+[tokenizer_pt.decode([i]) for i in sentence]+['<end>'],
        fontdict=fontdict, rotation=90)

    ax.set_yticklabels([tokenizer_en.decode([i]) for i in result
                        if i < tokenizer_en.vocab_size],
                       fontdict=fontdict)

    ax.set_xlabel('Head {}'.format(head+1))

  plt.tight_layout()
  plt.show()

# %%
def translate(sentence, plot=''):
  result, attention_weights = evaluate(sentence)

  predicted_sentence = tokenizer_en.decode([i for i in result
                                            if i < tokenizer_en.vocab_size])

  print('Input: {}'.format(sentence))
  print('Predicted translation: {}'.format(predicted_sentence))

  if plot:
    plot_attention_weights(attention_weights, sentence, result, plot)

# %%
translate("Твой живот мягкий, как круглая котлета")
# Out:
# Input: Твой живот мягкий, как круглая котлета
# Predicted translation: i have to be a much .

# %%
translate("Твой живот мягкий, как круглая котлета, сделай выводы")

# %%
pip install sacremoses
# Out:
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacremoses) (2023.12.25)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.3.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sacremoses) (4.66.1)
# Installing collected packages: sacremoses
# Successfully installed sacremoses-0.1.1

# %%
from transformers import FSMTForConditionalGeneration, FSMTTokenizer
mname = "facebook/wmt19-ru-en"
tokenizer = FSMTTokenizer.from_pretrained(mname)
model = FSMTForConditionalGeneration.from_pretrained(mname)

input = "Твой живот мягкий, как круглая котлета"
input_ids = tokenizer.encode(input, return_tensors="pt")
outputs = model.generate(input_ids)
decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(decoded)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# vocab-src.json:   0%|          | 0.00/776k [00:00<?, ?B/s]
# vocab-tgt.json:   0%|          | 0.00/639k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/396k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.16G [00:00<?, ?B/s]
# Some weights of FSMTForConditionalGeneration were not initialized from the model checkpoint at facebook/wmt19-ru-en and are newly initialized: ['model.encoder.embed_positions.weight', 'model.decoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# generation_config.json:   0%|          | 0.00/260 [00:00<?, ?B/s]
# Your belly is as soft as a round patty

# %%
input = "Твой живот мягкий, как круглая котлет, делай выводы"
input_ids = tokenizer.encode(input, return_tensors="pt")
outputs = model.generate(input_ids)
decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(decoded)
# Out:
# Your belly is as soft as a round patty, draw conclusions

# %%
input = "Твой живот мягкий, как круглая котлета, делай выводы о проливных дождях."
input_ids = tokenizer.encode(input, return_tensors="pt")
outputs = model.generate(input_ids)
decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(decoded)
# Out:
# Your stomach is as soft as a round patty, draw conclusions about the torrential rains.

# %%
input = "Твой живот мягкий, как круглая котлета, делай выводы о проливных дождях на острове Хансю."
input_ids = tokenizer.encode(input, return_tensors="pt")
outputs = model.generate(input_ids)
decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(decoded)
# Out:
# Your stomach is as soft as a round patty, draw conclusions about the torrential rains on Hansu Island.

# %% [markdown]
# ### Вывод:
# Готовые библиотеки работают адекватно и быстро.
